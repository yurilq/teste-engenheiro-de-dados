# %%
import pandas as pd
import chardet

# %%
itens_prova = pd.read_csv("Dados/DADOS/ITENS_PROVA_2020.csv", sep = ";")

# %%
itens_prova
# Out:
#       CO_POSICAO SG_AREA  CO_ITEM TX_GABARITO  CO_HABILIDADE  IN_ITEM_ABAN  \
# 0             26      LC     7099           D             15             0
# 1             43      LC     7099           D             15             0
# 2             26      LC     7099           D             15             0
# 3             26      LC     7099           D             15             0
# 4             41      LC     7099           D             15             0
# ...          ...     ...      ...         ...            ...           ...
# 4410          13      LC   112157           E             20             0
# 4411          35      LC   112157           E             20             0
# 4412          28      LC   112157           E             20             0
# 4413          15      LC   112157           E             20             0
# 4414          15      LC   112157           E             20             0
#
# ...

# %%
with open("Dados/DADOS/MICRODADOS_ENEM_2020.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
micro_dados = pd.read_csv("Dados/DADOS/MICRODADOS_ENEM_2020.csv",encoding='ISO-8859-1',sep = ";")

# %%
micro_dados

# %%
import pyspark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import pyspark
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
docker
